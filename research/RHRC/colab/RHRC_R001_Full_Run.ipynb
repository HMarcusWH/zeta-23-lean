# %% [markdown]
# # RHRC R001 - one-click Colab run
# This notebook runs the fail-closed RHRC stack and ends by printing `FINAL_ANSWER.txt`. Numerical diagnostics cannot promote RH; only unconditional Lean/comparator closure can.

# %%
# !git clone https://github.com/HMarcusWH/zeta-23-lean.git
# %cd zeta-23-lean
# !python -m pip install -q -r research/RHRC/requirements.txt

# %%
# !python research/RHRC/runner/run_all.py --zeros 400 --grid 10800 --aperture-max 500 --output-dir /content/rhrc_final_output

# %%
print(open('/content/rhrc_final_output/FINAL_ANSWER.txt').read())
import json
display(json.load(open('/content/rhrc_final_output/FINAL_ANSWER.json')))

# %%
# !cd /content && zip -qr rhrc_final_output.zip rhrc_final_output
print('/content/rhrc_final_output.zip')
